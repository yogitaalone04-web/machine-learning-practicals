# %% [markdown]
# <a href="https://colab.research.google.com/github/yogitaalone04-web/machine-learning-practicals/blob/main/Week8_PCA_Dimensionality_Reduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CS24D017: Yogita Alone

# %% [markdown]
# AIM: To apply Principal Component Analysis for dimensionality reduction and visualize the transformed feature space.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import seaborn as sns

# %%
iris=load_iris()
X=iris.data
y=iris.target

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(X)

# %%
pca=PCA(n_components=2)
X_pca=pca.fit_transform(x_scaled)

# %%
print("Explained Variance Ratio:",pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.72962445 0.22850762]

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0],X_pca[:,1],c=y)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA-Iris Dataset")
plt.colorbar()
plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

pca = PCA()
pca.fit(x_scaled)

plt.plot(np.cumsum(pca.explained_variance_ratio_))  # underscore lagao
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.show()
