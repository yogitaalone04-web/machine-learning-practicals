# %% [markdown]
# <a href="https://colab.research.google.com/github/yogitaalone04-web/machine-learning-practicals/blob/main/Week10_Hierarchical_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CS24D017: Yogita Alone

# %% [markdown]
# AIM: To perform Hierarchical Clustering using agglomerative methods
# and interpret dendrograms for cluster formation.

# %%
import numpy as np
import pandas as pd
from scipy import cluster
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
path="/content/drive/MyDrive/ML_Dataset/Mall_Customers.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
X=df[['Annual Income (k$)','Spending Score (1-100)']]

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
plt.figure(figsize=(8,5))
dendrogram(linkage (X_scaled,method='ward'))
plt.title("Dendrogram")
plt.xlabel("Customer")
plt.ylabel("Euclidean Distance ")
plt.show()

# %%
from scipy import cluster
from sklearn import metrics
hc = AgglomerativeClustering(n_clusters=5,linkage='ward')
clusters=hc.fit_predict(X_scaled)

# %%
df['Cluster']= cluster
print(df.head())
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#                                              Cluster
# 0  <module 'scipy.cluster' from '/usr/local/lib/p...
# 1  <module 'scipy.cluster' from '/usr/local/lib/p...
# 2  <module 'scipy.cluster' from '/usr/local/lib/p...
# 3  <module 'scipy.cluster' from '/usr/local/lib/p...
# 4  <module 'scipy.cluster' from '/usr/local/lib/p...

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    x='Annual Income (k$)',
    y='Spending Score (1-100)',
    hue='Cluster',
    data=df,
    palette='Set1'
)
plt.title("Hierarchical Clustering")
plt.show()
